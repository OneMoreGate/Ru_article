# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np
import matplotlib.ticker as ticker

# %%
energy_O = pd.read_csv('oxygen.csv', delimiter=';')
energy_Si = pd.read_csv('silicon.csv', delimiter=';')
energy_Ru = pd.read_csv('ruthenium.csv', delimiter=';')

# %%
for j in energy_O.columns:
    energy_O[j] = [float(i.replace(',', '.')) for i in energy_O[j]] 

for j in energy_Si.columns:
    energy_Si[j] = [float(i.replace(',', '.')) for i in energy_Si[j]] 

for j in energy_1.columns:
    energy_1[j] = [float(i.replace(',', '.')) for i in energy_1[j]]

# %%
fig, ax = plt.subplots(figsize = [7,5])

ax.plot(energy_1['Binding Energy (E)'], energy_1['exp'], 'k', linewidth = 1, label = 'XPS measurements')
ax.plot(energy_1['Binding Energy (E)'], energy_1['O1s A'], 'c--', linewidth = 1, label = 'Fiting')
ax.plot(energy_1['Binding Energy (E)'], energy_1['O1s B'], 'g--', linewidth = 1)
ax.plot(energy_1['Binding Energy (E)'], energy_1['Backgnd.'], 'y--', linewidth = 1)
ax.plot(energy_1['Binding Energy (E)'], energy_1['Envelope'], 'b--', linewidth = 1)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.2))
ax.yaxis.set_major_locator(ticker.MultipleLocator(100))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(20))
ax.set_xlim([527,536])
ax.set_ylim([900,1400])
ax.set_xlabel('Bonding energy, eV')
ax.get_yaxis().set_visible(False)
ax.invert_xaxis()
ax.legend()

#plt.savefig('Si2p_XPS.png', dpi = 300, bbox_inches = 'tight')
